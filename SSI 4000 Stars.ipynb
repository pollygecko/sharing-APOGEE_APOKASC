# %%
import astropy
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt

# %%
hdul = fits.open(r"C:\Users\amber\OneDrive\Desktop\SSI\Selected_stars_final.fits")
hdul.info()
# Out:
# Filename: C:\Users\amber\OneDrive\Desktop\SSI\Selected_stars_final.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (20, 2, 4000)   float64

# %%
hdu = hdul[0]
data = hdu.data
data
# Out:
# array([[[1.02733700e+06, 6.96227980e+00, 7.42099991e+01, ...,
#          2.88849996e+01, 0.00000000e+00, 7.40675000e+01],
#         [0.00000000e+00, 3.09767991e-01, 0.00000000e+00, ...,
#          3.29800018e-01, 0.00000000e+00, 2.00000000e-03]],
#
#        [[1.16144700e+06, 4.16810989e+00, 3.63199997e+01, ...,
#          5.85422713e+01, 0.00000000e+00, 3.64126000e+01],
#         [0.00000000e+00, 8.03358018e-01, 0.00000000e+00, ...,
#          4.85437113e-01, 0.00000000e+00, 3.80000000e-03]],
#
#        [[1.16345300e+06, 4.44000006e+00, 4.03300018e+01, ...,
#          2.53728516e+01, 0.00000000e+00, 4.03300000e+01],
#         [0.00000000e+00, 3.15701991e-01, 0.00000000e+00, ...,
#          2.22888550e-01, 0.00000000e+00, 3.70000000e-03]],
#
#        ...,
#
#        [[1.27846830e+07, 3.74499989e+00, 2.87199993e+01, ...,
#          1.05284650e+01, 0.00000000e+00, 2.92100000e+01],
#         [0.00000000e+00, 1.44336998e+00, 0.00000000e+00, ...,
#          9.80607243e-02, 0.00000000e+00, 9.80000000e-03]],
#
#        [[1.27849480e+07, 4.17999983e+00, 3.40800018e+01, ...,
#          2.82936748e+01, 0.00000000e+00, 3.40630000e+01],
#         [0.00000000e+00, 8.14481974e-01, 0.00000000e+00, ...,
#          2.30952782e-01, 0.00000000e+00, 3.20000000e-03]],
#
#        [[1.28841160e+07, 5.39584017e+00, 5.05999985e+01, ...,
#          3.13097621e+01, 0.00000000e+00, 5.05600000e+01],
#         [0.00000000e+00, 4.46209997e-01, 0.00000000e+00, ...,
#          3.07980962e-01, 0.00000000e+00, 2.30000000e-03]]])

# %%
data_USE = np.transpose(data)
Teff = np.array(data_USE[4,1,:])
nu_max = np.array(data_USE[2,0,:])

# %%
Teff
# Out:
# array([4673., 4784., 5026., ..., 4991., 4889., 4644.])

# %%
nu_max
# Out:
# array([74.20999908, 36.31999969, 40.33000183, ..., 28.71999931,
#        34.08000183, 50.59999847])

# %%
from matplotlib.pyplot import figure
figure(figsize=(8,8), dpi=100)
plt.grid()
plt.plot(Teff, nu_max, 'bx')
plt.xlim(6000, 4000)
plt.ylim(200, 10)
plt.xlabel('Teff')
plt.ylabel('nu_max')
plt.show()

# %%
hdul = fits.open(r"C:\Users\amber\OneDrive\Desktop\SSI\APOKASC_cat_v6.5.4.fits")
hdul.info()
# Out:
# Filename: C:\Users\amber\OneDrive\Desktop\SSI\APOKASC_cat_v6.5.4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  Joined        1 BinTableHDU   1129   23363R x 430C   [20A, K, 20A, 20A, D, D, D, D, E, E, E, E, E, E, E, E, E, E, 23A, D, D, D, D, D, D, D, D, D, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 5A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, J, E, E, E, E, E, E, 8A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, J, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 5A, E, E, E, E, E, E, E, E, E, E, E, E, J, 1A, 1A, 1A, 1A, 1A, 2A, 8A, 5A, 8A, E, 5A, 12A, J, 5A, 8A, 9A, E, E, 1A, 18A, E, 1A, 2A, 200A, 200A, 20A]

# %%
hdu = hdul[0]
data = hdu.data
data
